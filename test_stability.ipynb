# %%
import sys
import os

#Use if working on Colab
#from google.colab import drive
#drive.mount('/content/drive')
#PATH = '/content/drive/My Drive/PPM_Stability/'

#If working locally
PATH = os.getcwd()
sys.path.append(PATH)

# %%
#!pip install lime==0.2.0.1
#!pip install shap==0.37.0
#!pip install xgboost==1.0.0
#!pip install anchor-exp==0.0.2.0

# %%
import EncoderFactory
#from DatasetManager_for_colab import DatasetManager
from DatasetManager import DatasetManager
import BucketFactory
import stability as st #Nogueira, Sechidis, Brown.

import pandas as pd
import numpy as np
from scipy import stats

from sklearn.metrics import roc_auc_score
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.preprocessing import StandardScaler

import time
import os
import sys
from sys import argv
import pickle
from collections import defaultdict
import random
import joblib

from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

import lime
import lime.lime_tabular
from lime import submodular_pick

from anchor import anchor_tabular
#from alibi.utils.data import gen_category_map

import shap

import warnings
warnings.filterwarnings('ignore')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

def imp_df(column_names, importances):
        df = pd.DataFrame({'feature': column_names,
                       'feature_importance': importances}) \
           .sort_values('feature_importance', ascending = False) \
           .reset_index(drop = True)
        return df

# plotting a feature importance dataframe (horizontal barchart)
def var_imp_plot(imp_df, title, num_feat):
        imp_df.columns = ['feature', 'feature_importance']
        b= sns.barplot(x = 'feature_importance', y = 'feature', data = imp_df.head(num_feat), orient = 'h', palette="Blues_r")

# %%
from lime import submodular_pick

def generate_lime_explanations(explainer,test_xi, cls, submod=False, test_all_data=None, max_feat = 10, scaler=None):
    
    #print("Actual value ", test_y)
    
#     print(type(test_xi))
#     print(type(cls.predict_proba))
#     print(type(max_feat))

    def scale_predict_fn(X):
        scaled_data = scaler.transform(X)
        pred = cls.predict_proba(scaled_data)
        return pred

    def predict_fn(X):
        #X = X.reshape(1, -1)
        pred = cls.predict_proba(X)
        return pred

    if scaler == None:
        exp = explainer.explain_instance(test_xi, 
                                 predict_fn, num_features=max_feat, labels=[0,1])
    else:
        exp = explainer.explain_instance(test_xi, 
                                 scale_predict_fn, num_features=max_feat, labels=[0,1])
        
    return exp
        
    if submod==True:
        sp_obj=submodular_pick.SubmodularPick(explainer, test_all_data, cls.predict_proba, 
                                      sample_size=20, num_features=num_features,num_exps_desired=4)
        [exp.as_pyplot_figure(label=exp.available_labels()[0]) for exp in sp_obj.sp_explanations];

# %%
def dispersal(weights, features):
    
    feat_len = len(features)
    weights_by_feat = []
    
    #Weights are sorted by iteration. Transpose list.
    for i in list(range(feat_len)):
        feat_weight = []
        for iteration in weights:
            feat_weight.append(iteration[i])
        weights_by_feat.append(feat_weight)
    
    dispersal = []
    dispersal_no_outlier = []
    
    for each in weights_by_feat:
        #Find mean and variance of weight for each feature
        mean = np.mean(each)
        std_dev = np.std(each)
        var = std_dev**2
        
        #Calculate relative variance, ignore features where the weight is always 0
        if mean == 0:
            dispersal.append(0)
            dispersal_no_outlier.append(0)
        else:
            rel_var = var/abs(mean)
            dispersal.append(rel_var)
            
            #dispersal without outliers - remove anything with a z-score higher
            #than 3 (more than 3 standard deviations away from the mean)
            rem_outlier = []
            z_scores = stats.zscore(each)

            for i in range(len(z_scores)):
                if -3 < z_scores[i] < 3:
                    rem_outlier.append(each[i])
            if rem_outlier != []:
                new_mean = np.mean(rem_outlier)
                if new_mean == 0:
                    dispersal_no_outlier.append(0)
                else:
                    new_std = np.std(rem_outlier)
                    new_var = new_std**2
                    new_rel_var = new_var/abs(new_mean)
                    dispersal_no_outlier.append(new_rel_var)
            else:
                dispersal_no_outlier.append(rel_var)

    return dispersal, dispersal_no_outlier

# %%
def create_samples(shap_explainer, iterations, row, features, top = None, scaler = None):
    length = len(features)
    
    exp = []
    rel_exp = []
    
    if scaler != None:
        row = scaler.transform(row)
    
    for j in range(iterations):
        #Generate shap values for row
        shap_values = shap_explainer(row).values
        #shap_values = [val[0] for val in shap_explanation]
        
        if scaler != None:
            shap_values = scaler.inverse_transform(shap_values)
        
        #Map SHAP values to feature names
        importances = []
        
        abs_values = []
    
        for i in range(length):
            feat = features[i]
            shap_val = shap_values[0][i]
            abs_val = abs(shap_values[0][i])
            entry = (feat, shap_val, abs_val)
            importances.append(entry)
            abs_values.append(abs_val)
        
        #Sort features by influence on result
        importances.sort(key=lambda tup: tup[2], reverse = True)
        
        #Create list of all feature
        exp.append(importances)
        
        #print(exp[0])
        
        #Create list of most important features
        rel_feat = []
        if top != None:
            for i in range(top):
                feat = importances[i]
                if feat[2] > 0:
                    rel_feat.append(feat)

            rel_exp.append(rel_feat)
        else:
            bins = pd.cut(abs_values, 4, duplicates = "drop", retbins = True)[-1]
            q1_min = bins[-2]
            rel_feat = [feat for feat in importances if feat[2] > q1_min]
            rel_exp.append(rel_feat)
        
    return exp, rel_exp

# %%
dataset_ref = "sepsis_cases"
params_dir = PATH + "params"
results_dir = "results"
bucket_method = "single"
cls_encoding = "agg"
cls_method = "xgboost"

gap = 1
n_iter = 1

method_name = "%s_%s"%(bucket_method, cls_encoding)

generate_lime = True
generate_shap = True
generate_anchor = False

sample_size = 2
exp_iter = 10
max_feat = 10
max_prefix = 20

dataset_ref_to_datasets = {
    #"bpic2011": ["bpic2011_f%s"%formula for formula in range(1,5)],
    "bpic2015": ["bpic2015_%s_f2"%(municipality) for municipality in range(5,6)],
    "bpic2017" : ["bpic2017_accepted"],
    "bpic2012" : ["bpic2012_accepted"],
    #"insurance": ["insurance_activity", "insurance_followup"],
    "sepsis_cases": ["sepsis_cases_1"],# "sepsis_cases_2", "sepsis_cases_4"]
    "production": ["production"] 
}

datasets = [dataset_ref] if dataset_ref not in dataset_ref_to_datasets else dataset_ref_to_datasets[dataset_ref]

datasets
# Out:
# ['sepsis_cases_1']

# %%
for dataset_name in datasets:

    min_prefix_length = 1

    dataset_manager = DatasetManager(dataset_name)
    data = dataset_manager.read_dataset()

    all_pipelines = []
    all_cls = []
    all_encoders = []
    all_scalers = []
    all_train = []
    all_samples = []
    all_results = []
    
    for ii in range(n_iter):
        num_buckets = len([name for name in os.listdir(os.path.join(PATH,'%s/%s/%s/pipelines'% (dataset_ref, cls_method, method_name)))])

        for bucket in range(num_buckets):
            bucketID = bucket+1
            print ('Bucket', bucketID)

            #import everything needed to sort and predict
            pipeline_path = os.path.join(PATH, "%s/%s/%s/pipelines/pipeline_bucket_%s.joblib" % 
                                         (dataset_ref, cls_method, method_name, bucketID))
            pipeline = joblib.load(pipeline_path)
            feature_combiner = pipeline['encoder']
            if 'scaler' in pipeline.named_steps:
                scaler = pipeline['scaler']
            else:
                scaler = None
            cls = pipeline['cls']
            
            all_cls.append(cls)
            all_encoders.append(feature_combiner)
            all_scalers.append(scaler)
            all_pipelines.append(pipeline)

            #find relevant samples for bucket
            bucket_sample = pd.read_csv(os.path.join(PATH, "%s/%s/%s/samples/test_sample_bucket_%s.csv" % 
                                      (dataset_ref, cls_method, method_name, bucketID))).values
            results_template = pd.read_csv(os.path.join(PATH, "%s/%s/%s/samples/results_bucket_%s.csv" % 
                                      (dataset_ref, cls_method, method_name, bucketID)))
    
            if scaler != None:
                bucket_sample = scaler.transform(bucket_sample)
            bucket_results = results_template
            
            feat_names = feature_combiner.get_feature_names()
            feat_list = [feat.replace(" ", "_") for feat in feat_names]
            
            all_samples.append(bucket_sample)
            all_results.append(bucket_results)
            
            #import training data for bucket
            train_data = pd.read_csv(os.path.join(PATH, "%s/%s/%s/train_data/train_data_bucket_%s.csv" % 
                                                          (dataset_ref, cls_method, method_name, bucketID))).values
            if scaler != None:
                train_data = scaler.transform(train_data)
            
            all_train.append(train_data)
# Out:
# Bucket 1

# %%
if generate_shap:

    for dataset_name in datasets:
        
        for ii in range(n_iter):
            num_buckets = len([name for name in os.listdir(os.path.join(PATH,'%s/%s/%s/pipelines'% 
                                                                        (dataset_ref, cls_method, method_name)))])
            
            for bucket in range(num_buckets):
                bucketID = bucket+1
                print ('Bucket', bucketID)

                cls = all_cls[bucket]
                feature_combiner = all_encoders[bucket]
                scaler = all_scalers[bucket]
                trainingdata = all_train[bucket]
                sample_instances = all_samples[bucket]
                results = all_results[bucket]
                
                if cls_method == "xgboost":
                    shap_explainer = shap.Explainer(cls)
                else:
                    shap_explainer = shap.Explainer(cls, trainingdata)
                print(type(shap_explainer))
                
                feat_list = [feat.replace(" ", "_") for feat in feature_combiner.get_feature_names()]
                
                subset_stability = []
                weight_stability = []
                adjusted_weight_stability = []
                    
                #explain the chosen instances and find the stability score
                instance_no = 0
                for instance in sample_instances:
                    instance_no += 1    
                    print("Testing", instance_no, "of", len(sample_instances), ".")
                    
                    #if cls_method == "xgboost":
                    instance = instance.reshape(1, -1)

                    #Get Tree SHAP explanations for instance
                    exp, rel_exp = create_samples(shap_explainer, exp_iter, instance, feat_list, scaler = scaler)

                    feat_pres = []
                    feat_weights = []

                    for iteration in rel_exp:
                        #print("Computing feature presence for iteration", rel_exp.index(iteration))

                        presence_list = [0]*len(feat_list)

                        for each in feat_list:
                            list_idx = feat_list.index(each)

                            for explanation in iteration:
                                if each in explanation[0]:
                                    presence_list[list_idx] = 1

                        feat_pres.append(presence_list)

                    for iteration in exp:
                        #print("Compiling feature weights for iteration", exp.index(iteration))

                        weights = [0]*len(feat_list)

                        for each in feat_list:
                            list_idx = feat_list.index(each)

                            for explanation in iteration:
                                if each in explanation[0]:

                                    weights[list_idx] = explanation[1]
                        feat_weights.append(weights)

                    stability = st.getStability(feat_pres)
                    print ("Stability:", round(stability,2))
                    subset_stability.append(stability)

                    rel_var, second_var = dispersal(feat_weights, feat_list)
                    avg_dispersal = 1-np.mean(rel_var)
                    print ("Dispersal of feature importance:", round(avg_dispersal, 2))
                    weight_stability.append(avg_dispersal)
                    adj_dispersal = 1-np.mean(second_var)
                    print ("Dispersal with no outliers:", round(adj_dispersal, 2))
                    adjusted_weight_stability.append(adj_dispersal)
                    
                results["SHAP Subset Stability"] = subset_stability
                results["SHAP Weight Stability"] = weight_stability
                results["SHAP Adjusted Weight Stability"] = adjusted_weight_stability
                all_results[bucket] = results
# Out:
# Bucket 1
# <class 'shap.explainers._tree.Tree'>
# Testing 1 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 2 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 3 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 4 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 5 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 6 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 7 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 8 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 9 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 10 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 11 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 12 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 13 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 14 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 15 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 16 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 17 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 18 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 19 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 20 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 21 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 22 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 23 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 24 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 25 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 26 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 27 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 28 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 29 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 30 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 31 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 32 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 33 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 34 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 35 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 36 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 37 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 38 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 39 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 40 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 41 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 42 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 43 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 44 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 45 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 46 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 47 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 48 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 49 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 50 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 51 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 52 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 53 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 54 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 55 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 56 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 57 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 58 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 59 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 60 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 61 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 62 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 63 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 64 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 65 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 66 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 67 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 68 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 69 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 70 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 71 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 72 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 73 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 74 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 75 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 76 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 77 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 78 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 79 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 80 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 81 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 82 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 83 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 84 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 85 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 86 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 87 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 88 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 89 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 90 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 91 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 92 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 93 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 94 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 95 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 96 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 97 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 98 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 99 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 100 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 101 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 102 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 103 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 104 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 105 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 106 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 107 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 108 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 109 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 110 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 111 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 112 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 113 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 114 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 115 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 116 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 117 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 118 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 119 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 120 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 121 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 122 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 123 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 124 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 125 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 126 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 127 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 128 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 129 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 130 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 131 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 132 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 133 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 134 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 135 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 136 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 137 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 138 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 139 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 140 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 141 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 142 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 143 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 144 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 145 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 146 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 147 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 148 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 149 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 150 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 151 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 152 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 153 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 154 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 155 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 156 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 157 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 158 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 159 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 160 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 161 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 162 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 163 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 164 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 165 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 166 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 167 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 168 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 169 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 170 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 171 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 172 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 173 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 174 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 175 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 176 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 177 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 178 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 179 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 180 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 181 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 182 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 183 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 184 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 185 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 186 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 187 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 188 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 189 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 190 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 191 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 192 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 193 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 194 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 195 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 196 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 197 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 198 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 199 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 200 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 201 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 202 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 203 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 204 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 205 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 206 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 207 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 208 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 209 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 210 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 211 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 212 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 213 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 214 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 215 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 216 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 217 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 218 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 219 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 220 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 221 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 222 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 223 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 224 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 225 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 226 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 227 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 228 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 229 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 230 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 231 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 232 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 233 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 234 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 235 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 236 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 237 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 238 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 239 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 240 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 241 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 242 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 243 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 244 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 245 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 246 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 247 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 248 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 249 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 250 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 251 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 252 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 253 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 254 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 255 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 256 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 257 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 258 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 259 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 260 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 261 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 262 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 263 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 264 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 265 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 266 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 267 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 268 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 269 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 270 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 271 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 272 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 273 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 274 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 275 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 276 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 277 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 278 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 279 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 280 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 281 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 282 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 283 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 284 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 285 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 286 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 287 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 288 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 289 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 290 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 291 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 292 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 293 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 294 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 295 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 296 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 297 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 298 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 299 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 300 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 301 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 302 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 303 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 304 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 305 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 306 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 307 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 308 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 309 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 310 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 311 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 312 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 313 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 314 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 315 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 316 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 317 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 318 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 319 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 320 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 321 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 322 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 323 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 324 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 325 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 326 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 327 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 328 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 329 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 330 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 331 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 332 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 333 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 334 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 335 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 336 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 337 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 338 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 339 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 340 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 341 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 342 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 343 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 344 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 345 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 346 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 347 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 348 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 349 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 350 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 351 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 352 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 353 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 354 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 355 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 356 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 357 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 358 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 359 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 360 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 361 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 362 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 363 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 364 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 365 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 366 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 367 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 368 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 369 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 370 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 371 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 372 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 373 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 374 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 375 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 376 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 377 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 378 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 379 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 380 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 381 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 382 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 383 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 384 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 385 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 386 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 387 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 388 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 389 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 390 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 391 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 392 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 393 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 394 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 395 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 396 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 397 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 398 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 399 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 400 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 401 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 402 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 403 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 404 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 405 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 406 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 407 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 408 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 409 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 410 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 411 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 412 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 413 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 414 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 415 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 416 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 417 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 418 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 419 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 420 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 421 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 422 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 423 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 424 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 425 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 426 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 427 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 428 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 429 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 430 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 431 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 432 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 433 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 434 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 435 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 436 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 437 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 438 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 439 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 440 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 441 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 442 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 443 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 444 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 445 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 446 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 447 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 448 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 449 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 450 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 451 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 452 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 453 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 454 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 455 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 456 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 457 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 458 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# ...
# Dispersal with no outliers: 1.0
# Testing 841 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 842 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 843 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 844 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 845 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 846 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 847 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 848 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 849 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 850 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 851 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 852 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 853 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 854 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 855 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 856 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 857 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 858 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 859 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 860 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 861 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 862 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 863 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 864 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 865 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 866 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 867 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 868 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 869 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 870 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 871 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 872 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 873 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 874 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 875 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 876 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 877 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 878 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 879 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 880 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 881 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 882 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 883 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 884 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 885 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 886 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 887 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 888 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 889 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 890 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 891 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 892 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 893 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 894 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 895 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 896 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 897 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 898 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 899 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 900 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 901 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 902 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 903 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 904 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 905 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 906 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 907 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 908 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 909 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 910 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 911 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 912 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 913 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 914 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 915 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 916 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 917 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 918 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 919 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 920 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 921 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 922 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 923 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 924 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 925 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 926 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 927 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 928 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 929 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 930 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 931 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 932 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 933 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 934 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 935 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 936 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 937 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 938 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 939 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 940 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 941 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 942 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 943 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 944 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 945 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 946 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 947 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 948 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 949 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 950 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 951 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 952 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 953 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 954 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 955 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 956 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 957 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 958 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 959 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 960 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 961 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 962 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 963 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 964 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 965 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 966 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 967 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 968 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 969 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 970 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 971 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 972 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 973 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 974 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 975 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 976 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 977 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 978 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 979 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 980 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 981 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 982 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 983 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 984 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 985 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 986 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 987 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 988 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 989 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 990 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 991 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0
# Testing 992 of 992 .
# Stability: 1.0
# Dispersal of feature importance: 1.0
# Dispersal with no outliers: 1.0

# %%
pd.concat(all_results).to_csv(os.path.join(PATH,"%s/%s/%s/samples/results.csv") % (dataset_ref, cls_method, method_name))

# %%
if generate_lime:

    for dataset_name in datasets:
        
        num_buckets = len([name for name in os.listdir(os.path.join(PATH,'%s/%s/%s/pipelines'% 
                                                                    (dataset_ref, cls_method, method_name)))])
            
        for bucket in range(num_buckets):
            bucketID = bucket+1
            print ('Bucket', bucketID)
            
            cls = all_cls[bucket]
            feature_combiner = all_encoders[bucket]
            scaler = all_scalers[bucket]
            trainingdata = all_train[bucket]
            sample_instances = all_samples[bucket]
            results = all_results[bucket]
            pipeline = all_pipelines[bucket]            

            feat_list = [feat.replace(" ", "_") for feat in feature_combiner.get_feature_names()]
            class_names = ["Negative", "Positive"]

            subset_stability = []
            weight_stability = []
            adjusted_weight_stability = []

            #create explainer now that can be passed later
            lime_explainer = lime.lime_tabular.LimeTabularExplainer(trainingdata,
                                  feature_names = feat_list, class_names=class_names)
            
            instance_no = 0
            print(len(sample_instances))
            #explain the chosen instances and find the stability score
            for instance in sample_instances:
                instance_no += 1

                print("Testing", instance_no, "of", len(sample_instances), ".")

                #Get lime explanations for instance
                feat_pres = []
                feat_weights = []
                
                for iteration in list(range(exp_iter)):

                    lime_exp = generate_lime_explanations(lime_explainer, instance, cls,
                                                          max_feat = len(feat_list), scaler = scaler)

                    all_weights = [exp[1] for exp in lime_exp.as_list()]
                    bins = pd.cut(all_weights, 4, duplicates = "drop", retbins = True)[-1]
                    q1_min = bins[-2]

                    presence_list = [0]*len(feat_list)
                    weights = [0]*len(feat_list)

                    for each in feat_list:
                        list_idx = feat_list.index(each)
                        #print ("Feature", list_idx)
                        for explanation in lime_exp.as_list():
                            if each in explanation[0]:
                                if explanation[1] > q1_min:
                                    presence_list[list_idx] = 1
                                weights[list_idx] = explanation[1]

                    feat_pres.append(presence_list)
                    feat_weights.append(weights)

                stability = st.getStability(feat_pres)
                print ("Stability:", round(stability,2))
                subset_stability.append(stability)

                rel_var, second_var = dispersal(feat_weights, feat_list)
                avg_dispersal = 1-np.mean(rel_var)
                print ("Dispersal of feature importance:", round(avg_dispersal, 2))
                weight_stability.append(avg_dispersal)
                adj_dispersal = 1-np.mean(second_var)
                print ("Dispersal with no outliers:", round(adj_dispersal, 2))
                adjusted_weight_stability.append(adj_dispersal)

            results["LIME Subset Stability"] = subset_stability
            results["LIME Weight Stability"] = weight_stability
            results["LIME Adjusted Weight Stability"] = adjusted_weight_stability
            all_results[bucket] = results
# Out:
# Bucket 1
# 992
# Testing 1 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.24
# Dispersal with no outliers: 0.24
# Testing 2 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.44
# Dispersal with no outliers: 0.44
# Testing 3 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.59
# Dispersal with no outliers: 0.59
# Testing 4 of 992 .
# Stability: 0.29
# Dispersal of feature importance: 0.17
# Dispersal with no outliers: 0.17
# Testing 5 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.15
# Dispersal with no outliers: 0.15
# Testing 6 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.44
# Dispersal with no outliers: 0.44
# Testing 7 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.48
# Dispersal with no outliers: 0.48
# Testing 8 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.41
# Dispersal with no outliers: 0.41
# Testing 9 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.35
# Dispersal with no outliers: 0.35
# Testing 10 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.45
# Dispersal with no outliers: 0.45
# Testing 11 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.01
# Dispersal with no outliers: 0.01
# Testing 12 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.39
# Dispersal with no outliers: 0.39
# Testing 13 of 992 .
# Stability: 0.17
# Dispersal of feature importance: 0.23
# Dispersal with no outliers: 0.23
# Testing 14 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.21
# Dispersal with no outliers: 0.21
# Testing 15 of 992 .
# Stability: 0.13
# Dispersal of feature importance: 0.57
# Dispersal with no outliers: 0.57
# Testing 16 of 992 .
# Stability: 0.26
# Dispersal of feature importance: 0.15
# Dispersal with no outliers: 0.15
# Testing 17 of 992 .
# Stability: 0.27
# Dispersal of feature importance: 0.49
# Dispersal with no outliers: 0.49
# Testing 18 of 992 .
# Stability: 0.18
# Dispersal of feature importance: -0.67
# Dispersal with no outliers: -0.67
# Testing 19 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.13
# Dispersal with no outliers: 0.13
# Testing 20 of 992 .
# Stability: 0.22
# Dispersal of feature importance: -1.03
# Dispersal with no outliers: -1.03
# Testing 21 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.34
# Dispersal with no outliers: 0.34
# Testing 22 of 992 .
# Stability: 0.2
# Dispersal of feature importance: -3.87
# Dispersal with no outliers: -3.87
# Testing 23 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.25
# Dispersal with no outliers: 0.25
# Testing 24 of 992 .
# Stability: 0.27
# Dispersal of feature importance: 0.29
# Dispersal with no outliers: 0.29
# Testing 25 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.34
# Dispersal with no outliers: 0.34
# Testing 26 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.38
# Dispersal with no outliers: 0.38
# Testing 27 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.44
# Dispersal with no outliers: 0.44
# Testing 28 of 992 .
# Stability: 0.17
# Dispersal of feature importance: 0.26
# Dispersal with no outliers: 0.26
# Testing 29 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.53
# Dispersal with no outliers: 0.53
# Testing 30 of 992 .
# Stability: 0.26
# Dispersal of feature importance: 0.38
# Dispersal with no outliers: 0.38
# Testing 31 of 992 .
# Stability: 0.17
# Dispersal of feature importance: 0.41
# Dispersal with no outliers: 0.41
# Testing 32 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.55
# Dispersal with no outliers: 0.55
# Testing 33 of 992 .
# Stability: 0.22
# Dispersal of feature importance: -1.98
# Dispersal with no outliers: -1.98
# Testing 34 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.46
# Dispersal with no outliers: 0.46
# Testing 35 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.5
# Dispersal with no outliers: 0.5
# Testing 36 of 992 .
# Stability: 0.22
# Dispersal of feature importance: -0.76
# Dispersal with no outliers: -0.76
# Testing 37 of 992 .
# Stability: 0.22
# Dispersal of feature importance: -0.11
# Dispersal with no outliers: -0.11
# Testing 38 of 992 .
# Stability: 0.29
# Dispersal of feature importance: 0.42
# Dispersal with no outliers: 0.42
# Testing 39 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.28
# Dispersal with no outliers: 0.28
# Testing 40 of 992 .
# Stability: 0.16
# Dispersal of feature importance: 0.29
# Dispersal with no outliers: 0.29
# Testing 41 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.47
# Dispersal with no outliers: 0.47
# Testing 42 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.4
# Dispersal with no outliers: 0.4
# Testing 43 of 992 .
# Stability: 0.2
# Dispersal of feature importance: -0.3
# Dispersal with no outliers: -0.3
# Testing 44 of 992 .
# Stability: 0.23
# Dispersal of feature importance: -0.48
# Dispersal with no outliers: -0.48
# Testing 45 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.29
# Dispersal with no outliers: 0.29
# Testing 46 of 992 .
# Stability: 0.18
# Dispersal of feature importance: -0.37
# Dispersal with no outliers: -0.37
# Testing 47 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.38
# Dispersal with no outliers: 0.38
# Testing 48 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.46
# Dispersal with no outliers: 0.46
# Testing 49 of 992 .
# Stability: 0.27
# Dispersal of feature importance: -0.08
# Dispersal with no outliers: -0.08
# Testing 50 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.45
# Dispersal with no outliers: 0.45
# Testing 51 of 992 .
# Stability: 0.17
# Dispersal of feature importance: 0.32
# Dispersal with no outliers: 0.32
# Testing 52 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.35
# Dispersal with no outliers: 0.35
# Testing 53 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.53
# Dispersal with no outliers: 0.53
# Testing 54 of 992 .
# Stability: 0.26
# Dispersal of feature importance: 0.02
# Dispersal with no outliers: 0.02
# Testing 55 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.27
# Dispersal with no outliers: 0.27
# Testing 56 of 992 .
# Stability: 0.16
# Dispersal of feature importance: 0.49
# Dispersal with no outliers: 0.49
# Testing 57 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.18
# Dispersal with no outliers: 0.18
# Testing 58 of 992 .
# Stability: 0.21
# Dispersal of feature importance: -0.5
# Dispersal with no outliers: -0.5
# Testing 59 of 992 .
# Stability: 0.29
# Dispersal of feature importance: 0.16
# Dispersal with no outliers: 0.16
# Testing 60 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.59
# Dispersal with no outliers: 0.59
# Testing 61 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.47
# Dispersal with no outliers: 0.47
# Testing 62 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.21
# Dispersal with no outliers: 0.21
# Testing 63 of 992 .
# Stability: 0.21
# Dispersal of feature importance: -1.17
# Dispersal with no outliers: -1.17
# Testing 64 of 992 .
# Stability: 0.22
# Dispersal of feature importance: -1.42
# Dispersal with no outliers: -1.42
# Testing 65 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.04
# Dispersal with no outliers: 0.04
# Testing 66 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.54
# Dispersal with no outliers: 0.54
# Testing 67 of 992 .
# Stability: 0.26
# Dispersal of feature importance: 0.54
# Dispersal with no outliers: 0.54
# Testing 68 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.36
# Dispersal with no outliers: 0.36
# Testing 69 of 992 .
# Stability: 0.21
# Dispersal of feature importance: -0.02
# Dispersal with no outliers: -0.02
# Testing 70 of 992 .
# Stability: 0.19
# Dispersal of feature importance: -0.91
# Dispersal with no outliers: -0.91
# Testing 71 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.34
# Dispersal with no outliers: 0.34
# Testing 72 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.35
# Dispersal with no outliers: 0.35
# Testing 73 of 992 .
# Stability: 0.22
# Dispersal of feature importance: -0.86
# Dispersal with no outliers: -0.86
# Testing 74 of 992 .
# Stability: 0.25
# Dispersal of feature importance: -0.15
# Dispersal with no outliers: -0.15
# Testing 75 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.14
# Dispersal with no outliers: 0.14
# Testing 76 of 992 .
# Stability: 0.18
# Dispersal of feature importance: -0.35
# Dispersal with no outliers: -0.35
# Testing 77 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.14
# Dispersal with no outliers: 0.14
# Testing 78 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.59
# Dispersal with no outliers: 0.59
# Testing 79 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.09
# Dispersal with no outliers: 0.09
# Testing 80 of 992 .
# Stability: 0.16
# Dispersal of feature importance: 0.54
# Dispersal with no outliers: 0.54
# Testing 81 of 992 .
# Stability: 0.23
# Dispersal of feature importance: -0.67
# Dispersal with no outliers: -0.67
# Testing 82 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.59
# Dispersal with no outliers: 0.59
# Testing 83 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.4
# Dispersal with no outliers: 0.4
# Testing 84 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.26
# Dispersal with no outliers: 0.26
# Testing 85 of 992 .
# Stability: 0.15
# Dispersal of feature importance: 0.43
# Dispersal with no outliers: 0.43
# Testing 86 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.61
# Dispersal with no outliers: 0.61
# Testing 87 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.22
# Dispersal with no outliers: 0.22
# Testing 88 of 992 .
# Stability: 0.22
# Dispersal of feature importance: -0.27
# Dispersal with no outliers: -0.27
# Testing 89 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.52
# Dispersal with no outliers: 0.52
# Testing 90 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.39
# Dispersal with no outliers: 0.39
# Testing 91 of 992 .
# Stability: 0.17
# Dispersal of feature importance: 0.05
# Dispersal with no outliers: 0.05
# Testing 92 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.54
# Dispersal with no outliers: 0.54
# Testing 93 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.37
# Dispersal with no outliers: 0.37
# Testing 94 of 992 .
# Stability: 0.15
# Dispersal of feature importance: 0.46
# Dispersal with no outliers: 0.46
# Testing 95 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.07
# Dispersal with no outliers: 0.07
# Testing 96 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.35
# Dispersal with no outliers: 0.35
# Testing 97 of 992 .
# Stability: 0.2
# Dispersal of feature importance: -0.4
# Dispersal with no outliers: -0.4
# Testing 98 of 992 .
# Stability: 0.23
# Dispersal of feature importance: -0.17
# Dispersal with no outliers: -0.17
# Testing 99 of 992 .
# Stability: 0.26
# Dispersal of feature importance: -1.47
# Dispersal with no outliers: -1.47
# Testing 100 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.17
# Dispersal with no outliers: 0.17
# Testing 101 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.58
# Dispersal with no outliers: 0.58
# Testing 102 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.56
# Dispersal with no outliers: 0.56
# Testing 103 of 992 .
# Stability: 0.23
# Dispersal of feature importance: -0.8
# Dispersal with no outliers: -0.8
# Testing 104 of 992 .
# Stability: 0.19
# Dispersal of feature importance: -0.4
# Dispersal with no outliers: -0.4
# Testing 105 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.54
# Dispersal with no outliers: 0.54
# Testing 106 of 992 .
# Stability: 0.27
# Dispersal of feature importance: 0.23
# Dispersal with no outliers: 0.23
# Testing 107 of 992 .
# Stability: 0.24
# Dispersal of feature importance: -0.25
# Dispersal with no outliers: -0.25
# Testing 108 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.25
# Dispersal with no outliers: 0.25
# Testing 109 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.49
# Dispersal with no outliers: 0.49
# Testing 110 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.37
# Dispersal with no outliers: 0.37
# Testing 111 of 992 .
# Stability: 0.26
# Dispersal of feature importance: 0.35
# Dispersal with no outliers: 0.35
# Testing 112 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.05
# Dispersal with no outliers: 0.05
# Testing 113 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.4
# Dispersal with no outliers: 0.4
# Testing 114 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.44
# Dispersal with no outliers: 0.44
# Testing 115 of 992 .
# Stability: 0.18
# Dispersal of feature importance: -10.33
# Dispersal with no outliers: -10.33
# Testing 116 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.52
# Dispersal with no outliers: 0.52
# Testing 117 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.49
# Dispersal with no outliers: 0.49
# Testing 118 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.52
# Dispersal with no outliers: 0.52
# Testing 119 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.32
# Dispersal with no outliers: 0.32
# Testing 120 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.08
# Dispersal with no outliers: 0.08
# Testing 121 of 992 .
# Stability: 0.27
# Dispersal of feature importance: 0.59
# Dispersal with no outliers: 0.59
# Testing 122 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.11
# Dispersal with no outliers: 0.11
# Testing 123 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.61
# Dispersal with no outliers: 0.61
# Testing 124 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.43
# Dispersal with no outliers: 0.43
# Testing 125 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.37
# Dispersal with no outliers: 0.37
# Testing 126 of 992 .
# Stability: 0.17
# Dispersal of feature importance: -0.56
# Dispersal with no outliers: -0.56
# Testing 127 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.29
# Dispersal with no outliers: 0.29
# Testing 128 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.13
# Dispersal with no outliers: 0.13
# Testing 129 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.39
# Dispersal with no outliers: 0.39
# Testing 130 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.07
# Dispersal with no outliers: 0.07
# Testing 131 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.33
# Dispersal with no outliers: 0.33
# Testing 132 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.56
# Dispersal with no outliers: 0.56
# Testing 133 of 992 .
# Stability: 0.26
# Dispersal of feature importance: 0.33
# Dispersal with no outliers: 0.33
# Testing 134 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.49
# Dispersal with no outliers: 0.49
# Testing 135 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.1
# Dispersal with no outliers: 0.1
# Testing 136 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.37
# Dispersal with no outliers: 0.37
# Testing 137 of 992 .
# Stability: 0.23
# Dispersal of feature importance: -0.07
# Dispersal with no outliers: -0.07
# Testing 138 of 992 .
# Stability: 0.23
# Dispersal of feature importance: -2.13
# Dispersal with no outliers: -2.13
# Testing 139 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.56
# Dispersal with no outliers: 0.56
# Testing 140 of 992 .
# Stability: 0.26
# Dispersal of feature importance: 0.49
# Dispersal with no outliers: 0.49
# Testing 141 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.53
# Dispersal with no outliers: 0.53
# Testing 142 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.37
# Dispersal with no outliers: 0.37
# Testing 143 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.48
# Dispersal with no outliers: 0.48
# Testing 144 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.4
# Dispersal with no outliers: 0.4
# Testing 145 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.47
# Dispersal with no outliers: 0.47
# Testing 146 of 992 .
# Stability: 0.21
# Dispersal of feature importance: -0.05
# Dispersal with no outliers: -0.05
# Testing 147 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.52
# Dispersal with no outliers: 0.52
# Testing 148 of 992 .
# Stability: 0.22
# Dispersal of feature importance: -2.37
# Dispersal with no outliers: -2.37
# Testing 149 of 992 .
# Stability: 0.26
# Dispersal of feature importance: 0.02
# Dispersal with no outliers: 0.02
# Testing 150 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.06
# Dispersal with no outliers: 0.06
# Testing 151 of 992 .
# Stability: 0.22
# Dispersal of feature importance: -0.59
# Dispersal with no outliers: -0.59
# Testing 152 of 992 .
# Stability: 0.23
# Dispersal of feature importance: -0.62
# Dispersal with no outliers: -0.62
# Testing 153 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.25
# Dispersal with no outliers: 0.25
# Testing 154 of 992 .
# Stability: 0.26
# Dispersal of feature importance: 0.33
# Dispersal with no outliers: 0.33
# Testing 155 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.14
# Dispersal with no outliers: 0.14
# Testing 156 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.54
# Dispersal with no outliers: 0.54
# Testing 157 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.28
# Dispersal with no outliers: 0.28
# Testing 158 of 992 .
# Stability: 0.26
# Dispersal of feature importance: -0.01
# Dispersal with no outliers: -0.01
# Testing 159 of 992 .
# Stability: 0.16
# Dispersal of feature importance: 0.07
# Dispersal with no outliers: 0.07
# Testing 160 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.51
# Dispersal with no outliers: 0.51
# Testing 161 of 992 .
# Stability: 0.22
# Dispersal of feature importance: -4.68
# Dispersal with no outliers: -4.68
# Testing 162 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.03
# Dispersal with no outliers: 0.03
# Testing 163 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.53
# Dispersal with no outliers: 0.53
# Testing 164 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.46
# Dispersal with no outliers: 0.46
# Testing 165 of 992 .
# Stability: 0.26
# Dispersal of feature importance: 0.5
# Dispersal with no outliers: 0.5
# Testing 166 of 992 .
# Stability: 0.18
# Dispersal of feature importance: -0.45
# Dispersal with no outliers: -0.45
# Testing 167 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.57
# Dispersal with no outliers: 0.57
# Testing 168 of 992 .
# Stability: 0.2
# Dispersal of feature importance: -0.38
# Dispersal with no outliers: -0.38
# Testing 169 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.29
# Dispersal with no outliers: 0.29
# Testing 170 of 992 .
# Stability: 0.19
# Dispersal of feature importance: -2.17
# Dispersal with no outliers: -2.17
# Testing 171 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.12
# Dispersal with no outliers: 0.12
# Testing 172 of 992 .
# Stability: 0.26
# Dispersal of feature importance: 0.19
# Dispersal with no outliers: 0.19
# Testing 173 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.45
# Dispersal with no outliers: 0.45
# Testing 174 of 992 .
# Stability: 0.21
# Dispersal of feature importance: -4.19
# Dispersal with no outliers: -4.19
# Testing 175 of 992 .
# Stability: 0.15
# Dispersal of feature importance: 0.52
# Dispersal with no outliers: 0.52
# Testing 176 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.5
# Dispersal with no outliers: 0.5
# Testing 177 of 992 .
# Stability: 0.18
# Dispersal of feature importance: -0.26
# Dispersal with no outliers: -0.26
# Testing 178 of 992 .
# Stability: 0.27
# Dispersal of feature importance: -0.25
# Dispersal with no outliers: -0.25
# Testing 179 of 992 .
# Stability: 0.17
# Dispersal of feature importance: 0.26
# Dispersal with no outliers: 0.26
# Testing 180 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.07
# Dispersal with no outliers: 0.07
# Testing 181 of 992 .
# Stability: 0.16
# Dispersal of feature importance: 0.24
# Dispersal with no outliers: 0.24
# Testing 182 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.03
# Dispersal with no outliers: 0.03
# Testing 183 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.24
# Dispersal with no outliers: 0.24
# Testing 184 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.46
# Dispersal with no outliers: 0.46
# Testing 185 of 992 .
# Stability: 0.15
# Dispersal of feature importance: 0.06
# Dispersal with no outliers: 0.06
# Testing 186 of 992 .
# Stability: 0.22
# Dispersal of feature importance: -0.02
# Dispersal with no outliers: -0.02
# Testing 187 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.46
# Dispersal with no outliers: 0.46
# Testing 188 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.45
# Dispersal with no outliers: 0.45
# Testing 189 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.34
# Dispersal with no outliers: 0.34
# Testing 190 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.47
# Dispersal with no outliers: 0.47
# Testing 191 of 992 .
# Stability: 0.14
# Dispersal of feature importance: 0.53
# Dispersal with no outliers: 0.53
# Testing 192 of 992 .
# Stability: 0.26
# Dispersal of feature importance: 0.23
# Dispersal with no outliers: 0.23
# Testing 193 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.41
# Dispersal with no outliers: 0.41
# Testing 194 of 992 .
# Stability: 0.23
# Dispersal of feature importance: -2.17
# Dispersal with no outliers: -2.17
# Testing 195 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.49
# Dispersal with no outliers: 0.49
# Testing 196 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.61
# Dispersal with no outliers: 0.61
# Testing 197 of 992 .
# Stability: 0.2
# Dispersal of feature importance: -0.44
# Dispersal with no outliers: -0.44
# Testing 198 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.47
# Dispersal with no outliers: 0.47
# Testing 199 of 992 .
# Stability: 0.24
# Dispersal of feature importance: -0.44
# Dispersal with no outliers: -0.44
# Testing 200 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.38
# Dispersal with no outliers: 0.38
# Testing 201 of 992 .
# Stability: 0.26
# Dispersal of feature importance: 0.21
# Dispersal with no outliers: 0.21
# Testing 202 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.12
# Dispersal with no outliers: 0.12
# Testing 203 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.26
# Dispersal with no outliers: 0.26
# Testing 204 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.47
# Dispersal with no outliers: 0.47
# Testing 205 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.46
# Dispersal with no outliers: 0.46
# Testing 206 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.19
# Dispersal with no outliers: 0.19
# Testing 207 of 992 .
# Stability: 0.28
# Dispersal of feature importance: -1.99
# Dispersal with no outliers: -1.99
# Testing 208 of 992 .
# Stability: 0.19
# Dispersal of feature importance: -4.0
# Dispersal with no outliers: -4.0
# Testing 209 of 992 .
# Stability: 0.16
# Dispersal of feature importance: 0.62
# Dispersal with no outliers: 0.62
# Testing 210 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.58
# Dispersal with no outliers: 0.58
# Testing 211 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.56
# Dispersal with no outliers: 0.56
# Testing 212 of 992 .
# Stability: 0.19
# Dispersal of feature importance: -21.81
# Dispersal with no outliers: -21.81
# Testing 213 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.55
# Dispersal with no outliers: 0.55
# Testing 214 of 992 .
# Stability: 0.22
# Dispersal of feature importance: -0.19
# Dispersal with no outliers: -0.19
# Testing 215 of 992 .
# Stability: 0.27
# Dispersal of feature importance: 0.6
# Dispersal with no outliers: 0.6
# Testing 216 of 992 .
# Stability: 0.17
# Dispersal of feature importance: -0.14
# Dispersal with no outliers: -0.14
# Testing 217 of 992 .
# Stability: 0.14
# Dispersal of feature importance: 0.39
# Dispersal with no outliers: 0.39
# Testing 218 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.58
# Dispersal with no outliers: 0.58
# Testing 219 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.64
# Dispersal with no outliers: 0.64
# Testing 220 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.47
# Dispersal with no outliers: 0.47
# Testing 221 of 992 .
# Stability: 0.17
# Dispersal of feature importance: 0.44
# Dispersal with no outliers: 0.44
# Testing 222 of 992 .
# Stability: 0.16
# Dispersal of feature importance: 0.57
# Dispersal with no outliers: 0.57
# Testing 223 of 992 .
# Stability: 0.23
# Dispersal of feature importance: -0.74
# Dispersal with no outliers: -0.74
# Testing 224 of 992 .
# Stability: 0.25
# Dispersal of feature importance: -0.42
# Dispersal with no outliers: -0.42
# Testing 225 of 992 .
# Stability: 0.15
# Dispersal of feature importance: 0.17
# Dispersal with no outliers: 0.17
# Testing 226 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.21
# Dispersal with no outliers: 0.21
# Testing 227 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.52
# Dispersal with no outliers: 0.52
# Testing 228 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.03
# Dispersal with no outliers: 0.03
# Testing 229 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.44
# Dispersal with no outliers: 0.44
# Testing 230 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.46
# Dispersal with no outliers: 0.46
# Testing 231 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.39
# Dispersal with no outliers: 0.39
# Testing 232 of 992 .
# Stability: 0.26
# Dispersal of feature importance: 0.36
# Dispersal with no outliers: 0.36
# Testing 233 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.01
# Dispersal with no outliers: 0.01
# Testing 234 of 992 .
# Stability: 0.27
# Dispersal of feature importance: -1.2
# Dispersal with no outliers: -1.2
# Testing 235 of 992 .
# Stability: 0.18
# Dispersal of feature importance: -0.56
# Dispersal with no outliers: -0.56
# Testing 236 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.64
# Dispersal with no outliers: 0.64
# Testing 237 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.24
# Dispersal with no outliers: 0.24
# Testing 238 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.56
# Dispersal with no outliers: 0.56
# Testing 239 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.04
# Dispersal with no outliers: 0.04
# Testing 240 of 992 .
# Stability: 0.21
# Dispersal of feature importance: -0.82
# Dispersal with no outliers: -0.82
# Testing 241 of 992 .
# Stability: 0.23
# Dispersal of feature importance: -0.08
# Dispersal with no outliers: -0.08
# Testing 242 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.17
# Dispersal with no outliers: 0.17
# Testing 243 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.05
# Dispersal with no outliers: 0.05
# Testing 244 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.49
# Dispersal with no outliers: 0.49
# Testing 245 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.05
# Dispersal with no outliers: 0.05
# Testing 246 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.47
# Dispersal with no outliers: 0.47
# Testing 247 of 992 .
# Stability: 0.28
# Dispersal of feature importance: 0.17
# Dispersal with no outliers: 0.17
# Testing 248 of 992 .
# Stability: 0.21
# Dispersal of feature importance: -0.25
# Dispersal with no outliers: -0.25
# Testing 249 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.38
# Dispersal with no outliers: 0.38
# Testing 250 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.2
# Dispersal with no outliers: 0.2
# Testing 251 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.39
# Dispersal with no outliers: 0.39
# Testing 252 of 992 .
# Stability: 0.25
# Dispersal of feature importance: -4.26
# Dispersal with no outliers: -4.26
# Testing 253 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.48
# Dispersal with no outliers: 0.48
# Testing 254 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.22
# Dispersal with no outliers: 0.22
# Testing 255 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.54
# Dispersal with no outliers: 0.54
# Testing 256 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.24
# Dispersal with no outliers: 0.24
# Testing 257 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.02
# Dispersal with no outliers: 0.02
# Testing 258 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.2
# Dispersal with no outliers: 0.2
# Testing 259 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.63
# Dispersal with no outliers: 0.63
# Testing 260 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.55
# Dispersal with no outliers: 0.55
# Testing 261 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.06
# Dispersal with no outliers: 0.06
# Testing 262 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.43
# Dispersal with no outliers: 0.43
# Testing 263 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.48
# Dispersal with no outliers: 0.48
# Testing 264 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.65
# Dispersal with no outliers: 0.65
# Testing 265 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.54
# Dispersal with no outliers: 0.54
# Testing 266 of 992 .
# Stability: 0.21
# Dispersal of feature importance: -2.1
# Dispersal with no outliers: -2.1
# Testing 267 of 992 .
# Stability: 0.26
# Dispersal of feature importance: 0.49
# Dispersal with no outliers: 0.49
# Testing 268 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.48
# Dispersal with no outliers: 0.48
# Testing 269 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.47
# Dispersal with no outliers: 0.47
# Testing 270 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.01
# Dispersal with no outliers: 0.01
# Testing 271 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.31
# Dispersal with no outliers: 0.31
# Testing 272 of 992 .
# Stability: 0.24
# Dispersal of feature importance: -0.06
# Dispersal with no outliers: -0.06
# Testing 273 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.09
# Dispersal with no outliers: 0.09
# Testing 274 of 992 .
# Stability: 0.18
# Dispersal of feature importance: -0.04
# Dispersal with no outliers: -0.04
# Testing 275 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.2
# Dispersal with no outliers: 0.2
# Testing 276 of 992 .
# Stability: 0.21
# Dispersal of feature importance: -0.13
# Dispersal with no outliers: -0.13
# Testing 277 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.53
# Dispersal with no outliers: 0.53
# Testing 278 of 992 .
# Stability: 0.25
# Dispersal of feature importance: -0.05
# Dispersal with no outliers: -0.05
# Testing 279 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.21
# Dispersal with no outliers: 0.21
# Testing 280 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.43
# Dispersal with no outliers: 0.43
# Testing 281 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.38
# Dispersal with no outliers: 0.38
# Testing 282 of 992 .
# Stability: 0.21
# Dispersal of feature importance: -0.93
# Dispersal with no outliers: -0.93
# Testing 283 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.25
# Dispersal with no outliers: 0.25
# Testing 284 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.52
# Dispersal with no outliers: 0.52
# Testing 285 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.48
# Dispersal with no outliers: 0.48
# Testing 286 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.02
# Dispersal with no outliers: 0.02
# Testing 287 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.62
# Dispersal with no outliers: 0.62
# Testing 288 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.59
# Dispersal with no outliers: 0.59
# Testing 289 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.44
# Dispersal with no outliers: 0.44
# Testing 290 of 992 .
# Stability: 0.2
# Dispersal of feature importance: -0.03
# Dispersal with no outliers: -0.03
# Testing 291 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.25
# Dispersal with no outliers: 0.25
# Testing 292 of 992 .
# Stability: 0.17
# Dispersal of feature importance: 0.45
# Dispersal with no outliers: 0.45
# Testing 293 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.55
# Dispersal with no outliers: 0.55
# Testing 294 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.16
# Dispersal with no outliers: 0.16
# Testing 295 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.36
# Dispersal with no outliers: 0.36
# Testing 296 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.43
# Dispersal with no outliers: 0.43
# Testing 297 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.46
# Dispersal with no outliers: 0.46
# Testing 298 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.06
# Dispersal with no outliers: 0.06
# Testing 299 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.28
# Dispersal with no outliers: 0.28
# Testing 300 of 992 .
# Stability: 0.18
# Dispersal of feature importance: -0.3
# Dispersal with no outliers: -0.3
# Testing 301 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.62
# Dispersal with no outliers: 0.62
# Testing 302 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.32
# Dispersal with no outliers: 0.32
# Testing 303 of 992 .
# Stability: 0.26
# Dispersal of feature importance: -0.96
# Dispersal with no outliers: -0.96
# Testing 304 of 992 .
# Stability: 0.22
# Dispersal of feature importance: -0.06
# Dispersal with no outliers: -0.06
# Testing 305 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.55
# Dispersal with no outliers: 0.55
# Testing 306 of 992 .
# Stability: 0.26
# Dispersal of feature importance: 0.21
# Dispersal with no outliers: 0.21
# Testing 307 of 992 .
# Stability: 0.16
# Dispersal of feature importance: 0.13
# Dispersal with no outliers: 0.13
# Testing 308 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.14
# Dispersal with no outliers: 0.14
# Testing 309 of 992 .
# Stability: 0.24
# Dispersal of feature importance: -0.07
# Dispersal with no outliers: -0.07
# Testing 310 of 992 .
# Stability: 0.25
# Dispersal of feature importance: -0.2
# Dispersal with no outliers: -0.2
# Testing 311 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.64
# Dispersal with no outliers: 0.64
# Testing 312 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.14
# Dispersal with no outliers: 0.14
# Testing 313 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.58
# Dispersal with no outliers: 0.58
# Testing 314 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.07
# Dispersal with no outliers: 0.07
# Testing 315 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.44
# Dispersal with no outliers: 0.44
# Testing 316 of 992 .
# Stability: 0.24
# Dispersal of feature importance: -2.57
# Dispersal with no outliers: -2.57
# Testing 317 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.37
# Dispersal with no outliers: 0.37
# Testing 318 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.11
# Dispersal with no outliers: 0.11
# Testing 319 of 992 .
# Stability: 0.3
# Dispersal of feature importance: 0.55
# Dispersal with no outliers: 0.55
# Testing 320 of 992 .
# Stability: 0.16
# Dispersal of feature importance: 0.24
# Dispersal with no outliers: 0.24
# Testing 321 of 992 .
# Stability: 0.18
# Dispersal of feature importance: -3.9
# Dispersal with no outliers: -3.9
# Testing 322 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.62
# Dispersal with no outliers: 0.62
# Testing 323 of 992 .
# Stability: 0.16
# Dispersal of feature importance: 0.38
# Dispersal with no outliers: 0.38
# Testing 324 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.1
# Dispersal with no outliers: 0.1
# Testing 325 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.55
# Dispersal with no outliers: 0.55
# Testing 326 of 992 .
# Stability: 0.14
# Dispersal of feature importance: 0.6
# Dispersal with no outliers: 0.6
# Testing 327 of 992 .
# Stability: 0.18
# Dispersal of feature importance: -4.19
# Dispersal with no outliers: -4.19
# Testing 328 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.45
# Dispersal with no outliers: 0.45
# Testing 329 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.23
# Dispersal with no outliers: 0.23
# Testing 330 of 992 .
# Stability: 0.26
# Dispersal of feature importance: 0.34
# Dispersal with no outliers: 0.34
# Testing 331 of 992 .
# Stability: 0.21
# Dispersal of feature importance: -0.04
# Dispersal with no outliers: -0.04
# Testing 332 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.47
# Dispersal with no outliers: 0.47
# Testing 333 of 992 .
# Stability: 0.2
# Dispersal of feature importance: -0.64
# Dispersal with no outliers: -0.64
# Testing 334 of 992 .
# Stability: 0.21
# Dispersal of feature importance: -2.54
# Dispersal with no outliers: -2.54
# Testing 335 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.52
# Dispersal with no outliers: 0.52
# Testing 336 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.07
# Dispersal with no outliers: 0.07
# Testing 337 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.08
# Dispersal with no outliers: 0.08
# Testing 338 of 992 .
# Stability: 0.23
# Dispersal of feature importance: -0.23
# Dispersal with no outliers: -0.23
# Testing 339 of 992 .
# Stability: 0.23
# Dispersal of feature importance: -0.49
# Dispersal with no outliers: -0.49
# Testing 340 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.24
# Dispersal with no outliers: 0.24
# Testing 341 of 992 .
# Stability: 0.18
# Dispersal of feature importance: -0.42
# Dispersal with no outliers: -0.42
# Testing 342 of 992 .
# Stability: 0.25
# Dispersal of feature importance: -1.99
# Dispersal with no outliers: -1.99
# Testing 343 of 992 .
# Stability: 0.25
# Dispersal of feature importance: -0.05
# Dispersal with no outliers: -0.05
# Testing 344 of 992 .
# Stability: 0.24
# Dispersal of feature importance: -0.89
# Dispersal with no outliers: -0.89
# Testing 345 of 992 .
# Stability: 0.22
# Dispersal of feature importance: -0.33
# Dispersal with no outliers: -0.33
# Testing 346 of 992 .
# Stability: 0.23
# Dispersal of feature importance: -3.71
# Dispersal with no outliers: -3.71
# Testing 347 of 992 .
# Stability: 0.24
# Dispersal of feature importance: -0.16
# Dispersal with no outliers: -0.16
# Testing 348 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.38
# Dispersal with no outliers: 0.38
# Testing 349 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.25
# Dispersal with no outliers: 0.25
# Testing 350 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.26
# Dispersal with no outliers: 0.26
# Testing 351 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.22
# Dispersal with no outliers: 0.22
# Testing 352 of 992 .
# Stability: 0.16
# Dispersal of feature importance: 0.28
# Dispersal with no outliers: 0.28
# Testing 353 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.1
# Dispersal with no outliers: 0.1
# Testing 354 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.31
# Dispersal with no outliers: 0.31
# Testing 355 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.33
# Dispersal with no outliers: 0.33
# Testing 356 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.26
# Dispersal with no outliers: 0.26
# Testing 357 of 992 .
# Stability: 0.25
# Dispersal of feature importance: -0.12
# Dispersal with no outliers: -0.12
# Testing 358 of 992 .
# Stability: 0.22
# Dispersal of feature importance: -3.5
# Dispersal with no outliers: -3.5
# Testing 359 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.46
# Dispersal with no outliers: 0.46
# Testing 360 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.36
# Dispersal with no outliers: 0.36
# Testing 361 of 992 .
# Stability: 0.22
# Dispersal of feature importance: -2.48
# Dispersal with no outliers: -2.48
# Testing 362 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.38
# Dispersal with no outliers: 0.38
# Testing 363 of 992 .
# Stability: 0.23
# Dispersal of feature importance: -0.07
# Dispersal with no outliers: -0.07
# Testing 364 of 992 .
# Stability: 0.18
# Dispersal of feature importance: -0.03
# Dispersal with no outliers: -0.03
# Testing 365 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.53
# Dispersal with no outliers: 0.53
# Testing 366 of 992 .
# Stability: 0.19
# Dispersal of feature importance: -0.04
# Dispersal with no outliers: -0.04
# Testing 367 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.3
# Dispersal with no outliers: 0.3
# Testing 368 of 992 .
# Stability: 0.15
# Dispersal of feature importance: 0.24
# Dispersal with no outliers: 0.24
# Testing 369 of 992 .
# Stability: 0.24
# Dispersal of feature importance: -1.9
# Dispersal with no outliers: -1.9
# Testing 370 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.44
# Dispersal with no outliers: 0.44
# Testing 371 of 992 .
# Stability: 0.22
# Dispersal of feature importance: -0.56
# Dispersal with no outliers: -0.56
# Testing 372 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.38
# Dispersal with no outliers: 0.38
# Testing 373 of 992 .
# Stability: 0.26
# Dispersal of feature importance: 0.01
# Dispersal with no outliers: 0.01
# Testing 374 of 992 .
# Stability: 0.18
# Dispersal of feature importance: -0.43
# Dispersal with no outliers: -0.43
# Testing 375 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.3
# Dispersal with no outliers: 0.3
# Testing 376 of 992 .
# Stability: 0.19
# Dispersal of feature importance: -0.23
# Dispersal with no outliers: -0.23
# Testing 377 of 992 .
# Stability: 0.26
# Dispersal of feature importance: -0.11
# Dispersal with no outliers: -0.11
# Testing 378 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.48
# Dispersal with no outliers: 0.48
# Testing 379 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.54
# Dispersal with no outliers: 0.54
# Testing 380 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.15
# Dispersal with no outliers: 0.15
# Testing 381 of 992 .
# Stability: 0.22
# Dispersal of feature importance: -2.23
# Dispersal with no outliers: -2.23
# Testing 382 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.54
# Dispersal with no outliers: 0.54
# Testing 383 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.38
# Dispersal with no outliers: 0.38
# Testing 384 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.51
# Dispersal with no outliers: 0.51
# Testing 385 of 992 .
# Stability: 0.27
# Dispersal of feature importance: 0.41
# Dispersal with no outliers: 0.41
# Testing 386 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.4
# Dispersal with no outliers: 0.4
# Testing 387 of 992 .
# Stability: 0.26
# Dispersal of feature importance: 0.01
# Dispersal with no outliers: 0.01
# Testing 388 of 992 .
# Stability: 0.26
# Dispersal of feature importance: -0.71
# Dispersal with no outliers: -0.71
# Testing 389 of 992 .
# Stability: 0.28
# Dispersal of feature importance: 0.46
# Dispersal with no outliers: 0.46
# Testing 390 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.39
# Dispersal with no outliers: 0.39
# Testing 391 of 992 .
# Stability: 0.2
# Dispersal of feature importance: -0.76
# Dispersal with no outliers: -0.76
# Testing 392 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.47
# Dispersal with no outliers: 0.47
# Testing 393 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.53
# Dispersal with no outliers: 0.53
# Testing 394 of 992 .
# Stability: 0.17
# Dispersal of feature importance: 0.09
# Dispersal with no outliers: 0.09
# Testing 395 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.36
# Dispersal with no outliers: 0.36
# Testing 396 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.64
# Dispersal with no outliers: 0.64
# Testing 397 of 992 .
# Stability: 0.17
# Dispersal of feature importance: 0.37
# Dispersal with no outliers: 0.37
# Testing 398 of 992 .
# Stability: 0.23
# Dispersal of feature importance: -0.53
# Dispersal with no outliers: -0.53
# Testing 399 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.35
# Dispersal with no outliers: 0.35
# Testing 400 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.16
# Dispersal with no outliers: 0.16
# Testing 401 of 992 .
# Stability: 0.2
# Dispersal of feature importance: -0.05
# Dispersal with no outliers: -0.05
# Testing 402 of 992 .
# Stability: 0.16
# Dispersal of feature importance: 0.51
# Dispersal with no outliers: 0.51
# Testing 403 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.55
# Dispersal with no outliers: 0.55
# Testing 404 of 992 .
# Stability: 0.21
# Dispersal of feature importance: -0.51
# Dispersal with no outliers: -0.51
# Testing 405 of 992 .
# Stability: 0.26
# Dispersal of feature importance: -3.17
# Dispersal with no outliers: -3.17
# Testing 406 of 992 .
# Stability: 0.22
# Dispersal of feature importance: -0.17
# Dispersal with no outliers: -0.17
# Testing 407 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.1
# Dispersal with no outliers: 0.1
# Testing 408 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.53
# Dispersal with no outliers: 0.53
# Testing 409 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.29
# Dispersal with no outliers: 0.29
# Testing 410 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.31
# Dispersal with no outliers: 0.31
# Testing 411 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.43
# Dispersal with no outliers: 0.43
# Testing 412 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.4
# Dispersal with no outliers: 0.4
# Testing 413 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.51
# Dispersal with no outliers: 0.51
# Testing 414 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.4
# Dispersal with no outliers: 0.4
# Testing 415 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.55
# Dispersal with no outliers: 0.55
# Testing 416 of 992 .
# Stability: 0.2
# Dispersal of feature importance: -0.16
# Dispersal with no outliers: -0.16
# Testing 417 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.59
# Dispersal with no outliers: 0.59
# Testing 418 of 992 .
# Stability: 0.2
# Dispersal of feature importance: -0.19
# Dispersal with no outliers: -0.19
# Testing 419 of 992 .
# Stability: 0.24
# Dispersal of feature importance: -2.79
# Dispersal with no outliers: -2.79
# Testing 420 of 992 .
# Stability: 0.21
# Dispersal of feature importance: -45.24
# Dispersal with no outliers: -45.24
# Testing 421 of 992 .
# Stability: 0.2
# Dispersal of feature importance: -0.19
# Dispersal with no outliers: -0.19
# Testing 422 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.63
# Dispersal with no outliers: 0.63
# Testing 423 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.44
# Dispersal with no outliers: 0.44
# Testing 424 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.53
# Dispersal with no outliers: 0.53
# Testing 425 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.51
# Dispersal with no outliers: 0.51
# Testing 426 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.36
# Dispersal with no outliers: 0.36
# Testing 427 of 992 .
# Stability: 0.2
# Dispersal of feature importance: -1.41
# Dispersal with no outliers: -1.41
# Testing 428 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.53
# Dispersal with no outliers: 0.53
# Testing 429 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.41
# Dispersal with no outliers: 0.41
# Testing 430 of 992 .
# Stability: 0.21
# Dispersal of feature importance: -0.38
# Dispersal with no outliers: -0.38
# Testing 431 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.25
# Dispersal with no outliers: 0.25
# Testing 432 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.07
# Dispersal with no outliers: 0.07
# Testing 433 of 992 .
# Stability: 0.27
# Dispersal of feature importance: 0.4
# Dispersal with no outliers: 0.4
# Testing 434 of 992 .
# Stability: 0.22
# Dispersal of feature importance: -0.05
# Dispersal with no outliers: -0.05
# Testing 435 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.38
# Dispersal with no outliers: 0.38
# Testing 436 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.42
# Dispersal with no outliers: 0.42
# Testing 437 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.34
# Dispersal with no outliers: 0.34
# Testing 438 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.24
# Dispersal with no outliers: 0.24
# Testing 439 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.46
# Dispersal with no outliers: 0.46
# Testing 440 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.18
# Dispersal with no outliers: 0.18
# Testing 441 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.12
# Dispersal with no outliers: 0.12
# Testing 442 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.56
# Dispersal with no outliers: 0.56
# Testing 443 of 992 .
# Stability: 0.24
# Dispersal of feature importance: -0.31
# Dispersal with no outliers: -0.31
# Testing 444 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.39
# Dispersal with no outliers: 0.39
# ...
# Stability: 0.21
# Dispersal of feature importance: 0.63
# Dispersal with no outliers: 0.63
# Testing 846 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.43
# Dispersal with no outliers: 0.43
# Testing 847 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.42
# Dispersal with no outliers: 0.42
# Testing 848 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.41
# Dispersal with no outliers: 0.41
# Testing 849 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.45
# Dispersal with no outliers: 0.45
# Testing 850 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.23
# Dispersal with no outliers: 0.23
# Testing 851 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.38
# Dispersal with no outliers: 0.38
# Testing 852 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.28
# Dispersal with no outliers: 0.28
# Testing 853 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.47
# Dispersal with no outliers: 0.47
# Testing 854 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.13
# Dispersal with no outliers: 0.13
# Testing 855 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.55
# Dispersal with no outliers: 0.55
# Testing 856 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.31
# Dispersal with no outliers: 0.31
# Testing 857 of 992 .
# Stability: 0.26
# Dispersal of feature importance: 0.46
# Dispersal with no outliers: 0.46
# Testing 858 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.51
# Dispersal with no outliers: 0.51
# Testing 859 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.21
# Dispersal with no outliers: 0.21
# Testing 860 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.33
# Dispersal with no outliers: 0.33
# Testing 861 of 992 .
# Stability: 0.2
# Dispersal of feature importance: -7.47
# Dispersal with no outliers: -7.47
# Testing 862 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.52
# Dispersal with no outliers: 0.52
# Testing 863 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.5
# Dispersal with no outliers: 0.5
# Testing 864 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.43
# Dispersal with no outliers: 0.43
# Testing 865 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.37
# Dispersal with no outliers: 0.37
# Testing 866 of 992 .
# Stability: 0.26
# Dispersal of feature importance: -0.03
# Dispersal with no outliers: -0.03
# Testing 867 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.42
# Dispersal with no outliers: 0.42
# Testing 868 of 992 .
# Stability: 0.22
# Dispersal of feature importance: -9.63
# Dispersal with no outliers: -9.63
# Testing 869 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.49
# Dispersal with no outliers: 0.49
# Testing 870 of 992 .
# Stability: 0.15
# Dispersal of feature importance: -2.48
# Dispersal with no outliers: -2.48
# Testing 871 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.41
# Dispersal with no outliers: 0.41
# Testing 872 of 992 .
# Stability: 0.22
# Dispersal of feature importance: -0.04
# Dispersal with no outliers: -0.04
# Testing 873 of 992 .
# Stability: 0.26
# Dispersal of feature importance: 0.67
# Dispersal with no outliers: 0.67
# Testing 874 of 992 .
# Stability: 0.19
# Dispersal of feature importance: -10.91
# Dispersal with no outliers: -10.91
# Testing 875 of 992 .
# Stability: 0.29
# Dispersal of feature importance: -0.11
# Dispersal with no outliers: -0.11
# Testing 876 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.42
# Dispersal with no outliers: 0.42
# Testing 877 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.43
# Dispersal with no outliers: 0.43
# Testing 878 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.32
# Dispersal with no outliers: 0.32
# Testing 879 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.43
# Dispersal with no outliers: 0.43
# Testing 880 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.08
# Dispersal with no outliers: 0.08
# Testing 881 of 992 .
# Stability: 0.25
# Dispersal of feature importance: -19.14
# Dispersal with no outliers: -19.14
# Testing 882 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.34
# Dispersal with no outliers: 0.34
# Testing 883 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.12
# Dispersal with no outliers: 0.12
# Testing 884 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.18
# Dispersal with no outliers: 0.18
# Testing 885 of 992 .
# Stability: 0.22
# Dispersal of feature importance: -46.47
# Dispersal with no outliers: -46.47
# Testing 886 of 992 .
# Stability: 0.2
# Dispersal of feature importance: -4.15
# Dispersal with no outliers: -4.15
# Testing 887 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.19
# Dispersal with no outliers: 0.19
# Testing 888 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.61
# Dispersal with no outliers: 0.61
# Testing 889 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.38
# Dispersal with no outliers: 0.38
# Testing 890 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.47
# Dispersal with no outliers: 0.47
# Testing 891 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.53
# Dispersal with no outliers: 0.53
# Testing 892 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.09
# Dispersal with no outliers: 0.09
# Testing 893 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.41
# Dispersal with no outliers: 0.41
# Testing 894 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.02
# Dispersal with no outliers: 0.02
# Testing 895 of 992 .
# Stability: 0.2
# Dispersal of feature importance: -4.48
# Dispersal with no outliers: -4.48
# Testing 896 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.34
# Dispersal with no outliers: 0.34
# Testing 897 of 992 .
# Stability: 0.24
# Dispersal of feature importance: -0.11
# Dispersal with no outliers: -0.11
# Testing 898 of 992 .
# Stability: 0.23
# Dispersal of feature importance: -0.37
# Dispersal with no outliers: -0.37
# Testing 899 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.41
# Dispersal with no outliers: 0.41
# Testing 900 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.39
# Dispersal with no outliers: 0.39
# Testing 901 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.58
# Dispersal with no outliers: 0.58
# Testing 902 of 992 .
# Stability: 0.21
# Dispersal of feature importance: -1.41
# Dispersal with no outliers: -1.41
# Testing 903 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.08
# Dispersal with no outliers: 0.08
# Testing 904 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.39
# Dispersal with no outliers: 0.39
# Testing 905 of 992 .
# Stability: 0.21
# Dispersal of feature importance: -0.0
# Dispersal with no outliers: -0.0
# Testing 906 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.25
# Dispersal with no outliers: 0.25
# Testing 907 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.68
# Dispersal with no outliers: 0.68
# Testing 908 of 992 .
# Stability: 0.19
# Dispersal of feature importance: -2.49
# Dispersal with no outliers: -2.49
# Testing 909 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.59
# Dispersal with no outliers: 0.59
# Testing 910 of 992 .
# Stability: 0.27
# Dispersal of feature importance: 0.04
# Dispersal with no outliers: 0.04
# Testing 911 of 992 .
# Stability: 0.22
# Dispersal of feature importance: -2.26
# Dispersal with no outliers: -2.26
# Testing 912 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.48
# Dispersal with no outliers: 0.48
# Testing 913 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.32
# Dispersal with no outliers: 0.32
# Testing 914 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.44
# Dispersal with no outliers: 0.44
# Testing 915 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.21
# Dispersal with no outliers: 0.21
# Testing 916 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.26
# Dispersal with no outliers: 0.26
# Testing 917 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.58
# Dispersal with no outliers: 0.58
# Testing 918 of 992 .
# Stability: 0.13
# Dispersal of feature importance: 0.32
# Dispersal with no outliers: 0.32
# Testing 919 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.4
# Dispersal with no outliers: 0.4
# Testing 920 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.45
# Dispersal with no outliers: 0.45
# Testing 921 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.6
# Dispersal with no outliers: 0.6
# Testing 922 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.51
# Dispersal with no outliers: 0.51
# Testing 923 of 992 .
# Stability: 0.25
# Dispersal of feature importance: -11.66
# Dispersal with no outliers: -11.66
# Testing 924 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.51
# Dispersal with no outliers: 0.51
# Testing 925 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.5
# Dispersal with no outliers: 0.5
# Testing 926 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.55
# Dispersal with no outliers: 0.55
# Testing 927 of 992 .
# Stability: 0.15
# Dispersal of feature importance: 0.12
# Dispersal with no outliers: 0.12
# Testing 928 of 992 .
# Stability: 0.2
# Dispersal of feature importance: -0.15
# Dispersal with no outliers: -0.15
# Testing 929 of 992 .
# Stability: 0.26
# Dispersal of feature importance: 0.21
# Dispersal with no outliers: 0.21
# Testing 930 of 992 .
# Stability: 0.27
# Dispersal of feature importance: -2.17
# Dispersal with no outliers: -2.17
# Testing 931 of 992 .
# Stability: 0.25
# Dispersal of feature importance: -0.03
# Dispersal with no outliers: -0.03
# Testing 932 of 992 .
# Stability: 0.17
# Dispersal of feature importance: -0.0
# Dispersal with no outliers: -0.0
# Testing 933 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.6
# Dispersal with no outliers: 0.6
# Testing 934 of 992 .
# Stability: 0.2
# Dispersal of feature importance: 0.43
# Dispersal with no outliers: 0.43
# Testing 935 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.37
# Dispersal with no outliers: 0.37
# Testing 936 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.31
# Dispersal with no outliers: 0.31
# Testing 937 of 992 .
# Stability: 0.24
# Dispersal of feature importance: -0.83
# Dispersal with no outliers: -0.83
# Testing 938 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.19
# Dispersal with no outliers: 0.19
# Testing 939 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.65
# Dispersal with no outliers: 0.65
# Testing 940 of 992 .
# Stability: 0.21
# Dispersal of feature importance: -3.51
# Dispersal with no outliers: -3.51
# Testing 941 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.17
# Dispersal with no outliers: 0.17
# Testing 942 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.48
# Dispersal with no outliers: 0.48
# Testing 943 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.42
# Dispersal with no outliers: 0.42
# Testing 944 of 992 .
# Stability: 0.17
# Dispersal of feature importance: 0.37
# Dispersal with no outliers: 0.37
# Testing 945 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.46
# Dispersal with no outliers: 0.46
# Testing 946 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.1
# Dispersal with no outliers: 0.1
# Testing 947 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.6
# Dispersal with no outliers: 0.6
# Testing 948 of 992 .
# Stability: 0.2
# Dispersal of feature importance: -0.03
# Dispersal with no outliers: -0.03
# Testing 949 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.35
# Dispersal with no outliers: 0.35
# Testing 950 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.56
# Dispersal with no outliers: 0.56
# Testing 951 of 992 .
# Stability: 0.22
# Dispersal of feature importance: -0.89
# Dispersal with no outliers: -0.89
# Testing 952 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.21
# Dispersal with no outliers: 0.21
# Testing 953 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.32
# Dispersal with no outliers: 0.32
# Testing 954 of 992 .
# Stability: 0.21
# Dispersal of feature importance: -1.39
# Dispersal with no outliers: -1.39
# Testing 955 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.35
# Dispersal with no outliers: 0.35
# Testing 956 of 992 .
# Stability: 0.27
# Dispersal of feature importance: -0.14
# Dispersal with no outliers: -0.14
# Testing 957 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.39
# Dispersal with no outliers: 0.39
# Testing 958 of 992 .
# Stability: 0.23
# Dispersal of feature importance: -1.26
# Dispersal with no outliers: -1.26
# Testing 959 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.2
# Dispersal with no outliers: 0.2
# Testing 960 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.59
# Dispersal with no outliers: 0.59
# Testing 961 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.37
# Dispersal with no outliers: 0.37
# Testing 962 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.45
# Dispersal with no outliers: 0.45
# Testing 963 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.59
# Dispersal with no outliers: 0.59
# Testing 964 of 992 .
# Stability: 0.28
# Dispersal of feature importance: -0.55
# Dispersal with no outliers: -0.55
# Testing 965 of 992 .
# Stability: 0.21
# Dispersal of feature importance: 0.47
# Dispersal with no outliers: 0.47
# Testing 966 of 992 .
# Stability: 0.26
# Dispersal of feature importance: 0.5
# Dispersal with no outliers: 0.5
# Testing 967 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.1
# Dispersal with no outliers: 0.1
# Testing 968 of 992 .
# Stability: 0.2
# Dispersal of feature importance: -2.08
# Dispersal with no outliers: -2.08
# Testing 969 of 992 .
# Stability: 0.17
# Dispersal of feature importance: 0.61
# Dispersal with no outliers: 0.61
# Testing 970 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.25
# Dispersal with no outliers: 0.25
# Testing 971 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.19
# Dispersal with no outliers: 0.19
# Testing 972 of 992 .
# Stability: 0.24
# Dispersal of feature importance: -0.23
# Dispersal with no outliers: -0.23
# Testing 973 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.38
# Dispersal with no outliers: 0.38
# Testing 974 of 992 .
# Stability: 0.26
# Dispersal of feature importance: 0.37
# Dispersal with no outliers: 0.37
# Testing 975 of 992 .
# Stability: 0.21
# Dispersal of feature importance: -0.29
# Dispersal with no outliers: -0.29
# Testing 976 of 992 .
# Stability: 0.2
# Dispersal of feature importance: -0.24
# Dispersal with no outliers: -0.24
# Testing 977 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.59
# Dispersal with no outliers: 0.59
# Testing 978 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.03
# Dispersal with no outliers: 0.03
# Testing 979 of 992 .
# Stability: 0.28
# Dispersal of feature importance: -0.06
# Dispersal with no outliers: -0.06
# Testing 980 of 992 .
# Stability: 0.26
# Dispersal of feature importance: 0.61
# Dispersal with no outliers: 0.61
# Testing 981 of 992 .
# Stability: 0.22
# Dispersal of feature importance: 0.49
# Dispersal with no outliers: 0.49
# Testing 982 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.3
# Dispersal with no outliers: 0.3
# Testing 983 of 992 .
# Stability: 0.23
# Dispersal of feature importance: -0.84
# Dispersal with no outliers: -0.84
# Testing 984 of 992 .
# Stability: 0.24
# Dispersal of feature importance: -3.8
# Dispersal with no outliers: -3.8
# Testing 985 of 992 .
# Stability: 0.25
# Dispersal of feature importance: -2.87
# Dispersal with no outliers: -2.87
# Testing 986 of 992 .
# Stability: 0.25
# Dispersal of feature importance: 0.62
# Dispersal with no outliers: 0.62
# Testing 987 of 992 .
# Stability: 0.24
# Dispersal of feature importance: 0.42
# Dispersal with no outliers: 0.42
# Testing 988 of 992 .
# Stability: 0.18
# Dispersal of feature importance: 0.25
# Dispersal with no outliers: 0.25
# Testing 989 of 992 .
# Stability: 0.3
# Dispersal of feature importance: 0.43
# Dispersal with no outliers: 0.43
# Testing 990 of 992 .
# Stability: 0.23
# Dispersal of feature importance: 0.23
# Dispersal with no outliers: 0.23
# Testing 991 of 992 .
# Stability: 0.17
# Dispersal of feature importance: 0.41
# Dispersal with no outliers: 0.41
# Testing 992 of 992 .
# Stability: 0.19
# Dispersal of feature importance: 0.49
# Dispersal with no outliers: 0.49

# %%
pd.concat(all_results).to_csv(os.path.join(PATH,"%s/%s/%s/samples/results.csv") % (dataset_ref, cls_method, method_name))

# %%
all_results
# Out:
# [    Case ID  Actual  Prefix Length  Prediction  Prediction Probability  \
#  0     AAA_3       1              3           0                0.999815
#  1     AAA_4       1              4           0                0.999460
#  2       ABA       0              1           1                0.919434
#  3     ABA_5       0              5           0                0.999940
#  4    ADA_10       1             10           1                0.989788
#  ..      ...     ...            ...         ...                     ...
#  987    ZU_8       0              8           0                0.997607
#  988    ZW_6       0              6           1                0.906008
#  989    ZW_9       0              9           0                0.993170
#  990    ZX_9       0              9           0                0.946257
#  991   ZZ_12       0             12           0                0.999858
#
#       SHAP Subset Stability  SHAP Weight Stability  \
#  0                      1.0                    1.0
#  1                      1.0                    1.0
#  2                      1.0                    1.0
#  3                      1.0                    1.0
#  4                      1.0                    1.0
#  ..                     ...                    ...
#  987                    1.0                    1.0
#  988                    1.0                    1.0
#  989                    1.0                    1.0
#  990                    1.0                    1.0
#  991                    1.0                    1.0
#
#       SHAP Adjusted Weight Stability  LIME Subset Stability  \
#  0                               1.0               0.214166
#  1                               1.0               0.249801
#  2                               1.0               0.247390
#  3                               1.0               0.293019
#  4                               1.0               0.228614
#  ..                              ...                    ...
#  987                             1.0               0.178423
#  988                             1.0               0.298048
#  989                             1.0               0.227634
#  990                             1.0               0.165727
#  991                             1.0               0.186620
#
#       LIME Weight Stability  LIME Adjusted Weight Stability
#  0                 0.236844                        0.236844
#  1                 0.442541                        0.442541
#  2                 0.590118                        0.590118
#  3                 0.168044                        0.168044
#  4                 0.145379                        0.145379
#  ..                     ...                             ...
#  987               0.247370                        0.247370
#  988               0.433476                        0.433476
#  989               0.233417                        0.233417
#  990               0.410716                        0.410716
#  991               0.486170                        0.486170
#
#  [992 rows x 11 columns]]
